# %% [markdown]
# <center>
#     <img src="logo.png" width="175" alt="Descripción de la imagen">
# </center>

# %% [markdown]
# <span style="display: block; text-align: center; font-family: Time New Roman; font-size: 24px; color: black; text-decoration: underline">**Identify all companies in a country in Refinitiv via python**</span>

# %% [markdown]
# <span style="display: block; text-align: right; font-family: Time New Roman; font-size: 10px; color: black; text-decoration: underline">**Author: Luisa M Rodríguez-Fajardo** </span>

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 18px; color: black; text-decoration: underline">**Step 1. Import all libraries to be necessary**</span>

# %%
# Import Libraries

#Refinitiv Eikon Libraries 
import eikon as ek 
ek.set_app_key('Eikon Key') 
from datetime import datetime
import refinitiv.data as rd

# Others Libraries
import numpy as np
import pandas as pd
import cufflinks as cf
import matplotlib as plt
import yfinance as yf
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Ignore unnecessary warnings. 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black"> Remember that when using Python for downloader data from Refinitiv, you will need either each stock´s PermID or Ticket symbol. (Explined in the script "Variable Code Finder in Refinitiv"). In this case you will need the code of country. (Example: Mexico=MX, United State = US, etc.)</span>

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 18px; color: black;text-decoration: underline">**Step 2. Download Refinitiv data.**</span>

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black">This code returns the same information as if you use the Refinitiv screener. The main advantage of using python to know information about all the companies that operate in a country is mainly that you can obtain the complete list, whereas Refinitiv is limited to showing only 5,000 and you can export 10,000 to excel. With python you have access to the full list.</span>

# %%
# Extract all companies of one country from Refinitiv (Example: Mexico)

# You can specify between public companies, private companies, whether they are active or inactive. 
#Also, add the rest of the information you want to obtain.


df, err = ek.get_data('SCREEN(U(IN(Equity(active or inactive, private,primary))), IN(TR.HQCountryCode,"MX"))',
                      ['TR.CommonName','TR.OrganizationID','TR.HeadquartersCountry','TR.UltimateParent',
                       'TR.TRBCEconomicSector','TR.TRBCIndustry','TR.NAICSSector',
                       'TR.NAICSSubsector','TR.NAICSIndustryGroup','TR.NACEClassification'])

df
# Out:
#        Instrument                                Company Common Name  \
# 0      4295966676                  Siefore Banamex Basica 2 SA de CV
# 1      4296031399  Finde 1 SA de CV Sociedad de Inversion en Inst...
# 2      4296113089  Fondo de Inversiones Banamex SA de CV Fondo de...
# 3      4297258155  Asigna Compensacion y Liquidacion fideicomiso ...
# 4      4297968576  Fondo Liquido Finamex, S.A. de C.V., Fondo de ...
# ...           ...                                                ...
# 83944  5087060173                                  Kletos & Sanna SC
# 83945  5087060317  Fideicomiso No F/000239 Con GBM Grupo Bursatil...
# 83946  5087074256                                   Beliveo SA de CV
# 83947  5087074372                                 Legalario SA de CV
# 83948  5087074378                     Reboot Technologies SAPI de CV
#
#        Organization PermID Country of Headquarters  \
# 0               4295966676                  Mexico
# 1               4296031399                  Mexico
# 2               4296113089                  Mexico
# 3               4297258155                  Mexico
# 4               4297968576                  Mexico
# ...                    ...                     ...
# 83944           5087060173                  Mexico
# 83945           5087060317                  Mexico
# 83946           5087074256                  Mexico
# 83947           5087074372                  Mexico
# 83948           5087074378                  Mexico
#
#                             Organization Ultimate Parent  \
# 0                      Siefore Banamex Basica 2 SA de CV
# 1      Finde 1 SA de CV Sociedad de Inversion en Inst...
# 2                                          Citigroup Inc
# 3      Asigna Compensacion y Liquidacion fideicomiso ...
# 4      Fondo Liquido Finamex, S.A. de C.V., Fondo de ...
# ...                                                  ...
# 83944
# 83945
# 83946
# 83947
# 83948
#
#       TRBC Economic Sector Name            TRBC Industry Name  \
# 0                    Financials                 Pension Funds
# 1                    Financials  Corporate Financial Services
# 2                    Financials  Corporate Financial Services
# 3                   Industrials     Business Support Services
# 4
# ...                         ...                           ...
# 83944
# 83945
# 83946               Industrials     Business Support Services
# 83947                Technology                      Software
# 83948                Technology                      Software
#
#                                        NAICS Sector Name  \
# 0                                  Finance and Insurance
# 1                                  Finance and Insurance
# 2                                  Finance and Insurance
# 3                                  Finance and Insurance
# 4
# ...                                                  ...
# 83944
# 83945
# 83946  Administrative and Support and Waste Managemen...
# 83947                                        Information
# 83948                                        Information
#
#                                NAICS Subsector Name  \
# 0       Funds, Trusts, and Other Financial Vehicles
# 1       Funds, Trusts, and Other Financial Vehicles
# 2      Credit Intermediation and Related Activities
# 3      Credit Intermediation and Related Activities
# 4
# ...                                             ...
# 83944
# 83945
# 83946           Administrative and Support Services
# 83947                         Publishing Industries
# 83948                         Publishing Industries
#
#                          NAICS Industry Group Name  \
# 0             Insurance and Employee Benefit Funds
# 1                 Other Investment Pools and Funds
# 2              Nondepository Credit Intermediation
# 3      Activities Related to Credit Intermediation
# 4
# ...                                            ...
# 83944
# 83945
# 83946                    Business Support Services
# 83947                          Software Publishers
# 83948                          Software Publishers
#
#                                      NACE Classification
# 0                         Pension funding (NACE) (65.30)
# 1      Trusts, funds and similar financial entities (...
# 2      Other financial service activities, except ins...
# 3      Other activities auxiliary to financial servic...
# 4
# ...                                                  ...
# 83944
# 83945
# 83946
# 83947
# 83948
#
# [83949 rows x 11 columns]

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black">If you want to add filters to the search.</span>

# %%
# Define SCREENER syntax 

# Example:Companies in US that Market Cap is greater than 2,000M USD, in NYSE, in Energy business 
# and 6 months return is more than 5%"

syntax = 'SCREEN(U(IN(Equity(active,public,primary))),IN(TR.HQCountryCode,"US"), TR.CompanyMarketCap>=5000000000, \
IN(TR.ExchangeMarketIdCode,"XNYS"), IN(TR.TRBCBusinessSectorCode,"5010","5020","5030"), \
TR.TotalReturn6Mo>=5, CURN=USD)'

fields = ["TR.CommonName","TR.CompanyMarketCap","TR.ExchangeName","TR.TRBCBusinessSector","TR.TotalReturn3Mo"]

#Get data

df,e = ek.get_data(syntax, fields)

df
# Out:
#    Instrument              Company Common Name  Company Market Cap  \
# 0      DINO.N                 HF Sinclair Corp  10799732516.940001
# 1       OKE.N                        ONEOK Inc  41937827340.660004
# 2       EPD.N  Enterprise Products Partners LP      59183702831.75
# 3       VLO.N               Valero Energy Corp      47506803526.68
# 4        ET.N               Energy Transfer LP  49000872439.800003
# 5       CQP.N      Cheniere Energy Partners LP      25174874787.23
# 6      TRGP.N             Targa Resources Corp  21632680889.220001
# 7       MPC.N          Marathon Petroleum Corp       62563680000.0
# 8       PSX.N                      Phillips 66      63270011240.75
# 9       SUN.N                        Sunoco LP       5279289655.77
# 10     MPLX.N                          MPLX LP      39077501227.32
# 11      WES.N    Western Midstream Partners LP      11062902156.35
# 12     MUSA.N                   Murphy USA Inc       8280204087.04
# 13     HESM.N                Hess Midstream LP       7531566448.64
# 14       PR.N           Permian Resources Corp      11261770465.65
# 15       AM.N            Antero Midstream Corp        5953548580.0
# 16      DTM.N                 DT Midstream Inc        5304781713.2
#
#                     Exchange Name TRBC Business Sector Name  \
# 0   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 1   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 2   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 3   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 4   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 5   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 6   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 7   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 8   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 9   NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 10  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 11  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 12  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 13  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 14  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 15  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
# 16  NEW YORK STOCK EXCHANGE, INC.     Energy - Fossil Fuels
#
#     3 Month Total Return
# 0               11.97839
# 1                9.58016
# 2               5.706858
# 3               13.29863
# 4              10.044956
# 5             -10.521396
# 6              13.342095
# 7               14.94929
# 8              24.482255
# 9               15.39715
# 10             11.094724
# 11               4.18152
# 12              9.924592
# 13              8.324182
# 14              9.728507
# 15             -2.823309
# 16             -1.472743

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black">End
# </span>
