# %% [markdown]
# <center>
#     <img src="logo.png" width="175" alt="Descripción de la imagen">
# </center>

# %% [markdown]
# <span style="display: block; text-align: center; font-family: Time New Roman; font-size: 24px; color: black; text-decoration: underline">**Peer Analysis**</span>

# %% [markdown]
# <span style="display: block; text-align: right; font-family: Time New Roman; font-size: 10px; color: black; text-decoration: underline">**Author: Luisa M Rodríguez-Fajardo** </span>

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 18px; color: black; text-decoration: underline">**Step 1. Import all libraries to be necessary**</span>

# %%
# Import Libraries

#Refinitiv Eikon Libraries 
import eikon as ek 
ek.set_app_key('Eikon-key') 
from datetime import datetime
import refinitiv.data as rd

# Others Libraries
import numpy as np
import pandas as pd
import cufflinks as cf
import matplotlib as plt
import yfinance as yf
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Ignore unnecessary warnings. 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black"> Remember that when using Python for downloader data from Refinitiv, you will need either each stock´s PermID or Ticket symbol. (Explined in the script "Variable Code Finder in Refinitiv").</span>

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 18px; color: black;text-decoration: underline">**Step 2. Download Refinitiv data.**</span>

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black">This code returns the same information as if you use the Refinitiv Peer Analys.</span>

# %%
# Extract all competing companies of Apple

# You can specify between public companies, private companies, whether they are active or inactive. 
#Also, add the rest of the information you want to obtain.


apple, err = ek.get_data("Peers(AAPL.O)", ['TR.CommonName',"TR.PrimaryInstrument"]) # Identify Apple competition companies.
apple_comp, err = ek.get_data(apple['Primary Instrument RIC'].tolist(), 
                       ["TR.CommonName", # Company name
                        "TR.HeadquartersCountry", # Country of Headquarter 
                        "TR.CompanyMarketCap(scale=3, curn='USD')", # Market Capitalization, scale 1000 in USD (currency)
                        "TR.EV(scale=6, curn='USD')"]) # Enterprise Value
apple_comp



# Also, can add other variables such as: stock exchange name ("TR.ExchangeName"), industry clasifications 
# ("TR.TRBCIndustryGroup", 'TR.NAICSSector', 'TR.NAICSIndustryGroup'). Select scale and currency (EUR, CAD, etc...)
# Out:
#    Instrument                   Company Common Name   Country of Headquarters  \
# 0     CSCO.OQ                     Cisco Systems Inc  United States of America
# 1     QCOM.OQ                          Qualcomm Inc  United States of America
# 2     INTC.OQ                            Intel Corp  United States of America
# 3    NOKIA.HE                             Nokia Oyj                   Finland
# 4     2357.TW                  Asustek Computer Inc                    Taiwan
# 5     2354.TW             Foxconn Technology Co Ltd                    Taiwan
# 6      DELL.N                 Dell Technologies Inc  United States of America
# 7     NVDA.OQ                           NVIDIA Corp  United States of America
# 8     META.OQ                    Meta Platforms Inc  United States of America
# 9      ANET.N                   Arista Networks Inc  United States of America
# 10   GOOGL.OQ                          Alphabet Inc  United States of America
# ...

# %% [markdown]
# <span style="display: block; text-align: left; font-family: Time New Roman; font-size: 14px; color: black">End
# </span>
